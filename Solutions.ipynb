# %% [markdown]
# # Lab-customer-analysis-round-2

# %% [markdown]
# For this lab, we will be using the `marketing_customer_analysis.csv` file that you can find in the `files_for_lab` folder. Check out the `files_for_lab/about.md` to get more information if you are using the Online Excel.
#
# **Note**: For the next labs we will be using the same data file. Please save the code, so that you can re-use it later in the labs following this lab.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Show the dataframe shape.

# %%
#reading csv-file
df_marketing = pd.read_csv('marketing_customer_analysis.csv')

#showing the shape of my new dataframe
df_marketing.shape
# Out:
# (10910, 26)

# %% [markdown]
# ## 2. Standardize header names.

# %%
#only lower case
df_marketing.columns = df_marketing.columns.str.lower()

#removing spaces
df_marketing.columns = df_marketing.columns.str.replace(' ','_')

#checking
df_marketing.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
#renaming column employment status
df_marketing = df_marketing.rename(columns={'employmentstatus':'employment_status'})
df_marketing.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employment_status', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %% [markdown]
# ## 3. Which columns are numerical?

# %%
df_marketing.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
#way 1
#why does this not show the integers?

df_marketing.select_dtypes(include=[int, float])
# Out:
#        customer_lifetime_value  months_since_last_claim  \
# 0                  4809.216960                      7.0
# 1                  2228.525238                      3.0
# 2                 14947.917300                     34.0
# 3                 22332.439460                     10.0
# 4                  9025.067525                      NaN
# ...                        ...                      ...
# 10905             15563.369440                      NaN
# 10906              5259.444853                      7.0
# 10907             23893.304100                     11.0
# 10908             11971.977650                      0.0
# 10909              6857.519928                     31.0
#
#        number_of_open_complaints  total_claim_amount
# 0                            0.0          292.800000
# 1                            0.0          744.924331
# 2                            0.0          480.000000
# 3                            0.0          484.013411
# ...

# %%
#way2
df_marketing._get_numeric_data()
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %% [markdown]
# ## 4. Which columns are categorical?

# %%
df_marketing.select_dtypes('object')
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %% [markdown]
# ## 5. Check and deal with `NaN` values.

# %%
#checking for NaN values
df_marketing.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employment_status                   0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
#checking for vehicle types
df_marketing['vehicle_type'].unique()
# Out:
# array([nan, 'A'], dtype=object)

# %%
#will drop vehicle types completly as approx. 50% are missing and other values ('A') doesn't seem relevant
df_marketing = df_marketing.drop(['vehicle_type'], axis=1)
df_marketing
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employment_status gender  ...  \
# ...

# %%
#removing column "Unnamed"
df_marketing = df_marketing.drop(['unnamed:_0'], axis=1)
df_marketing
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employment_status gender  \
# ...

# %%
#removing rows with NaN values
df_marketing = df_marketing.dropna()
df_marketing
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employment_status gender  \
# ...

# %% [markdown]
# ## 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. _Hint_: If data from March does not exist, consider only January and February.

# %%
#changing column data type
df_marketing['effective_to_date'] = pd.to_datetime(df_marketing['effective_to_date'])
df_marketing['effective_to_date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 6       2011-02-14
#            ...
# 10903   2011-01-07
# 10904   2011-02-24
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %%
import datetime as dt

# %%
#creating lambda function
y = lambda x: [x].month()

#creating new column with only month using lambda funtion --> doesn't work, gives me an error
df_marketing['effective_to_month'] = df_marketing['effective_to_date'].apply(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-67ce442071ea> in <module>
#       3
#       4 #creating new column with only month using lambda funtion --> doesn't work, gives me an error
# ----> 5 df_marketing['effective_to_month'] = df_marketing['effective_to_date'].apply(y)
#
# c:\users\katha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-35-67ce442071ea> in <lambda>(x)
#       1 #creating lambda function
# ----> 2 y = lambda x: [x].month()
#       3
# ...

# %%
#import datetime as dt
#creating new column with only month using datetime
df_marketing['effective_to_month'] = df_marketing['effective_to_date'].dt.month
df_marketing['effective_to_month']
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 6        2
#         ..
# 10903    1
# 10904    2
# 10906    1
# 10907    2
# 10908    2
# Name: effective_to_month, Length: 9134, dtype: int64

# %%
df_marketing.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 6  IW72280  California              5035.035257       No     Basic    Doctor
#
#   effective_to_date employment_status gender  income  ...  \
# 0        2011-02-18          Employed      M   48029  ...
# 1        2011-01-18        Unemployed      F       0  ...
# 2        2011-02-10          Employed      M   22139  ...
# 3        2011-01-11          Employed      M   49078  ...
# 6        2011-02-14          Employed      F   37405  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %%
#checking unique values for months
df_marketing['effective_to_month'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
#no need to create filter as the current data frame only contains values for january and february (=first quarter)

#how to create a new data frame for first quarter (filter for january, february, march = 1,2,3)
filtered_first_quarter = df_marketing[df_marketing['effective_to_month']<=3]

filtered_first_quarter
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employment_status gender  \
# ...

# %% [markdown]
# ## 7. Put all the previously mentioned data transformations into a function.

# %%
#what do we have to do here?

# %% [markdown]
# ## 8. BONUS

# %% [markdown]
# ### 8.1. List Comprehensions

# %% [markdown]
# #### 8.1.1 Find the capital letters (and not white space) in the sentence 'The Quick Brown Fox Jumped Over The Lazy Dog'.

# %%
string = 'The Quick Brown Fox Jumped Over The Lazy Dog'

#creating a function to count capital letters
count=0
for i in string:
    if i.isupper():
        count=count+1
print("The number of capital letters found in the string is: ",count)
# Out:
# The number of capital letters found in the string is:  9

# %% [markdown]
# #### 8.1.2. Use a list comprehension to create a list with the same elements rounded to 2 decimal positions.

# %%
a = [
    0.84062117, 0.48006452, 0.7876326 , 0.77109654,
    0.44409793, 0.09014516, 0.81835917, 0.87645456,
    0.7066597 , 0.09610873, 0.41247947, 0.57433389,
    0.29960807, 0.42315023, 0.34452557, 0.4751035 ,
    0.17003563, 0.46843998, 0.92796258, 0.69814654,
    0.41290051, 0.19561071, 0.16284783, 0.97016248,
    0.71725408, 0.87702738, 0.31244595, 0.76615487,
    0.20754036, 0.57871812, 0.07214068, 0.40356048,
    0.12149553, 0.53222417, 0.9976855 , 0.12536346,
    0.80930099, 0.50962849, 0.94555126, 0.33364763
]

# %%
#creating lambda function
y = lambda x: '%.2f' % x

#creating list with rounded values by list comprehension
a_round = [y(x) for x in a]

#converting values to mumeric
a_round = pd.to_numeric(a_round)
a_round
# Out:
# array([0.84, 0.48, 0.79, 0.77, 0.44, 0.09, 0.82, 0.88, 0.71, 0.1 , 0.41,
#        0.57, 0.3 , 0.42, 0.34, 0.48, 0.17, 0.47, 0.93, 0.7 , 0.41, 0.2 ,
#        0.16, 0.97, 0.72, 0.88, 0.31, 0.77, 0.21, 0.58, 0.07, 0.4 , 0.12,
#        0.53, 1.  , 0.13, 0.81, 0.51, 0.95, 0.33])

# %% [markdown]
# ### 8.2. Lambdas

# %% [markdown]
# #### 8.2.1. Using Lambda Expressions in List Comprehensions

# %% [markdown]
# In the following challenge, we will combine two lists using a lambda expression in a list comprehension.
#
# To do this, we will need to introduce the zip function. The zip function returns an iterator of tuples.
#
# The way zip function works with list has been shown below:

# %%
#zipping two lists
zipped = zip(a, a_round)

#assigning zipped to a new list of tuples
new_lst = list(zipped)
new_lst
# Out:
# [(0.84062117, 0.84),
#  (0.48006452, 0.48),
#  (0.7876326, 0.79),
#  (0.77109654, 0.77),
#  (0.44409793, 0.44),
#  (0.09014516, 0.09),
#  (0.81835917, 0.82),
#  (0.87645456, 0.88),
#  (0.7066597, 0.71),
#  (0.09610873, 0.1),
#  (0.41247947, 0.41),
#  (0.57433389, 0.57),
#  (0.29960807, 0.3),
#  (0.42315023, 0.42),
#  (0.34452557, 0.34),
#  (0.4751035, 0.48),
#  (0.17003563, 0.17),
#  (0.46843998, 0.47),
#  (0.92796258, 0.93),
#  (0.69814654, 0.7),
#  (0.41290051, 0.41),
#  (0.19561071, 0.2),
#  (0.16284783, 0.16),
#  (0.97016248, 0.97),
#  (0.71725408, 0.72),
#  (0.87702738, 0.88),
#  (0.31244595, 0.31),
#  (0.76615487, 0.77),
#  (0.20754036, 0.21),
#  (0.57871812, 0.58),
#  (0.07214068, 0.07),
#  (0.40356048, 0.4),
#  (0.12149553, 0.12),
#  (0.53222417, 0.53),
#  (0.9976855, 1.0),
#  (0.12536346, 0.13),
#  (0.80930099, 0.81),
#  (0.50962849, 0.51),
#  (0.94555126, 0.95),
#  (0.33364763, 0.33)]

# %% [markdown]
# In this exercise we will try to compare the elements on the same index in the two lists. We want to zip the two lists and then use a lambda expression to compare if: list1 element > list2 element

# %%
#creating lambda function for comparison of the two elements
c = lambda a,b: 'yay' if a>b else 'nö'

#creating new list showing the result of the comparison
comparison = [c(a,b) for a,b in new_lst]
comparison
# Out:
# ['yay',
#  'yay',
#  'nö',
#  'yay',
#  'yay',
#  'yay',
#  'nö',
#  'nö',
#  'nö',
#  'nö',
#  'yay',
#  'yay',
#  'nö',
#  'yay',
#  'yay',
#  'nö',
#  'yay',
#  'nö',
#  'nö',
#  'nö',
#  'yay',
#  'nö',
#  'yay',
#  'yay',
#  'nö',
#  'nö',
#  'yay',
#  'nö',
#  'nö',
#  'nö',
#  'yay',
#  'yay',
#  'yay',
#  'yay',
#  'nö',
#  'nö',
#  'nö',
#  'nö',
#  'nö',
#  'yay']

# %%
#counting how often a>b and a<b
print("a>b ", comparison.count('yay') , "times")
print("a<b ", comparison.count('nö') , "times")
# Out:
# a>b  19 times
# a<b  21 times
