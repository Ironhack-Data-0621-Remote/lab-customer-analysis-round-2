# %% [markdown]
# # Lab-customer-analysis-round-2

# %% [markdown]
# For this lab, we will be using the `marketing_customer_analysis.csv` file that you can find in the `files_for_lab` folder. Check out the `files_for_lab/about.md` to get more information if you are using the Online Excel.
#
# **Note**: For the next labs we will be using the same data file. Please save the code, so that you can re-use it later in the labs following this lab.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Show the dataframe shape.

# %%
df = pd.read_csv("marketing_customer_analysis.csv",index_col=0)
shape = df.shape
shape
# Out:
# (10910, 25)

# %% [markdown]
# ## 2. Standardize header names.

# %%
#first change the columns to lower case
df.columns = df.columns.str.lower()
#then replace the spaces with underscore
df.columns = df.columns.str.replace(' ','_')
df
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# ## 3. Which columns are numerical?

# %%
#shows all data types of df
df.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
#selects all numeric data (interger & float)
df.select_dtypes(include=['int64',"float64"])
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %% [markdown]
# ## 4. Which columns are categorical?

# %%
#selects all the categorical columns
df.select_dtypes(include='object')
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %% [markdown]
# ## 5. Check and deal with `NaN` values.

# %%
#first show all null values in the whole df
df.isnull().sum()
#columns: state & response don't seem to be important for the purpose of the data, so I wouldn't delete the nulls
#for the column months_since_last_claim I would replace the nulls with the mean so
#for number of open complaionts column: replace nulls with 0 because most customers never filed a complaint
#for columns: vehicle class, size & type - I wouldn't delete the nulls, otherwise we deleted important info like the total insurance claims etc
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# ...

# %%
# replace missing values with 0
df['number_of_open_complaints'] = df['number_of_open_complaints'].fillna(0)
#test to see if there are still null values
df['number_of_open_complaints'].isnull().sum()
# Out:
# 0

# %%
# work out mean of months since last complaint and replace null values in this column with mean
months_claims_mean = df['months_since_last_claim'].mean()
months_claims_mean
# Out:
# 15.149070740488469

# %%
df['months_since_last_claim'] = df['months_since_last_claim'].fillna(complaints_mean)
#test to see if there are still null values
df['months_since_last_claim'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim             0
# months_since_policy_inception       0
# number_of_open_complaints           0
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# ...

# %% [markdown]
# ## 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. _Hint_: If data from March does not exist, consider only January and February.

# %%
#convert the column effective_to_date to datetime format
pd.to_datetime(df['effective_to_date'])
df['effective_to_date'] = pd.to_datetime(df['effective_to_date'], errors='coerce')

# %%
#create variable with just the month extracted from the effective_to_date column
month = df.effective_to_date.dt.strftime('%m')
month
# Out:
# 0        02
# 1        01
# 2        02
# 3        01
# 4        01
#          ..
# 10905    01
# 10906    01
# 10907    02
# 10908    02
# 10909    01
# Name: effective_to_date, Length: 10910, dtype: object

# %%
#add new 'month' column to df
df.insert(7,"month",month)
#convert month column to integer so we can filter by number in the next step
df["month"] = pd.to_numeric(df['month'], errors='coerce')

# %%
#all of the data seems to anyway be in Q1
Q1 = df[(df['month']==1) | (df['month']==2) | (df['month']==3) ]
Q1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date  month employmentstatus gender  ...  \
# ...

# %% [markdown]
# ## 7. Put all the previously mentioned data transformations into a function.

# %% [markdown]
# ## 8. BONUS

# %% [markdown]
# ### 8.1. List Comprehensions

# %% [markdown]
# #### 8.1.1 Find the capital letters (and not white space) in the sentence 'The Quick Brown Fox Jumped Over The Lazy Dog'.

# %%
string = 'The Quick Brown Fox Jumped Over The Lazy Dog'
capital_letters = [letter for letter in string if letter.isupper()]
capital_letters
# Out:
# ['T', 'Q', 'B', 'F', 'J', 'O', 'T', 'L', 'D']

# %% [markdown]
# #### 8.1.2. Use a list comprehension to create a list with the same elements rounded to 2 decimal positions.

# %%
a = [
    0.84062117, 0.48006452, 0.7876326 , 0.77109654,
    0.44409793, 0.09014516, 0.81835917, 0.87645456,
    0.7066597 , 0.09610873, 0.41247947, 0.57433389,
    0.29960807, 0.42315023, 0.34452557, 0.4751035 ,
    0.17003563, 0.46843998, 0.92796258, 0.69814654,
    0.41290051, 0.19561071, 0.16284783, 0.97016248,
    0.71725408, 0.87702738, 0.31244595, 0.76615487,
    0.20754036, 0.57871812, 0.07214068, 0.40356048,
    0.12149553, 0.53222417, 0.9976855 , 0.12536346,
    0.80930099, 0.50962849, 0.94555126, 0.33364763
]

# %%
a_rounded = [round(number,2) for number in a]
print(a_rounded)
# Out:
# [0.84, 0.48, 0.79, 0.77, 0.44, 0.09, 0.82, 0.88, 0.71, 0.1, 0.41, 0.57, 0.3, 0.42, 0.34, 0.48, 0.17, 0.47, 0.93, 0.7, 0.41, 0.2, 0.16, 0.97, 0.72, 0.88, 0.31, 0.77, 0.21, 0.58, 0.07, 0.4, 0.12, 0.53, 1.0, 0.13, 0.81, 0.51, 0.95, 0.33]

# %% [markdown]
# ### 8.2. Lambdas

# %% [markdown]
# #### 8.2.1. Using Lambda Expressions in List Comprehensions

# %% [markdown]
# In the following challenge, we will combine two lists using a lambda expression in a list comprehension.
#
# To do this, we will need to introduce the zip function. The zip function returns an iterator of tuples.
#
# The way zip function works with list has been shown below:

# %% [markdown]
# In this exercise we will try to compare the elements on the same index in the two lists. We want to zip the two lists and then use a lambda expression to compare if: list1 element > list2 element
