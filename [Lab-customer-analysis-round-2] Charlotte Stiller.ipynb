# %% [markdown]
# # Lab-customer-analysis-round-2

# %% [markdown]
# For this lab, we will be using the `marketing_customer_analysis.csv` file that you can find in the `files_for_lab` folder. Check out the `files_for_lab/about.md` to get more information if you are using the Online Excel.
#
# **Note**: For the next labs we will be using the same data file. Please save the code, so that you can re-use it later in the labs following this lab.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Show the dataframe shape.

# %%
#first importing the dataframe, second looking at the data shape
data = pd.read_csv('marketing_customer_analysis.csv')
data.shape
# Out:
# (10910, 26)

# %% [markdown]
# ## 2. Standardize header names.

# %%
#standardizing header names with the lower function + replace the spaces with an underscore 
data.columns = data.columns.str.lower()
data.columns = data.columns.str.replace(' ','_')
data.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %% [markdown]
# ## 3. Which columns are numerical?

# %%
#function shows numerical columns
data._get_numeric_data()
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %% [markdown]
# ## 4. Which columns are categorical?

# %%
#function shows categorical columns
data.select_dtypes('object')
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %% [markdown]
# ## 5. Check and deal with `NaN` values.

# %%
#checking if there are NAN values 

data.isna().sum()

#droping the NaN values and checking if it is working by comparing the shape before and after 
data.dropna()
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %% [markdown]
# ## 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. _Hint_: If data from March does not exist, consider only January and February.

# %%
#converting "effective_to_date" into datetime format + ignoring the errors
pd.to_datetime(data["effective_to_date"])
data["effective_to_date"] = pd.to_datetime(data["effective_to_date"], errors="coerce")
#checking the data types again
data.dtypes
#creating a variable with the month and checking if it worked
month = data.effective_to_date.dt.strftime('%m')
month

#add a new column to data and put the data from the variable inside 
data.insert(7,"month",month)
#convering the "month" column to integer (it was dtype object before) + checking if it worked
data["month"] = pd.to_numeric(data['month'], errors='coerce')
data.dtypes
#filtering the first quarter of the column "month" 

Q1 = data[(data["month"]==1) | (data["month"]==2) | (data["month"]==3)]
Q1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education  month effective_to_date employmentstatus  ...  \
# ...

# %% [markdown]
# ## 7. Put all the previously mentioned data transformations into a function.

# %%
#did I get this one right? Not sure what to do here
def function_q1(data):
    if i in data["month"]==1 | data["month"]==2 | data["month"]==3: 
        Q1.append(i)

# %% [markdown]
# ## 8. BONUS

# %% [markdown]
# ### 8.1. List Comprehensions

# %% [markdown]
# #### 8.1.1 Find the capital letters (and not white space) in the sentence 'The Quick Brown Fox Jumped Over The Lazy Dog'.

# %%
sentence = 'The Quick Brown Fox Jumped Over The Lazy Dog'
capital_letters = [] 


#storing the captial letters in the list "capital_letters" + checking the list  
for i in sentence: 
    if i.isupper():
        capital_letters.append(i)
        
print(capital_letters)
# Out:
# ['T', 'Q', 'B', 'F', 'J', 'O', 'T', 'L', 'D']

# %% [markdown]
# #### 8.1.2. Use a list comprehension to create a list with the same elements rounded to 2 decimal positions.

# %%
a = [
    0.84062117, 0.48006452, 0.7876326 , 0.77109654,
    0.44409793, 0.09014516, 0.81835917, 0.87645456,
    0.7066597 , 0.09610873, 0.41247947, 0.57433389,
    0.29960807, 0.42315023, 0.34452557, 0.4751035 ,
    0.17003563, 0.46843998, 0.92796258, 0.69814654,
    0.41290051, 0.19561071, 0.16284783, 0.97016248,
    0.71725408, 0.87702738, 0.31244595, 0.76615487,
    0.20754036, 0.57871812, 0.07214068, 0.40356048,
    0.12149553, 0.53222417, 0.9976855 , 0.12536346,
    0.80930099, 0.50962849, 0.94555126, 0.33364763
]

# %%
rounded_a = [round(i,2) for i in a]
print(rounded_a)
# Out:
# [0.84, 0.48, 0.79, 0.77, 0.44, 0.09, 0.82, 0.88, 0.71, 0.1, 0.41, 0.57, 0.3, 0.42, 0.34, 0.48, 0.17, 0.47, 0.93, 0.7, 0.41, 0.2, 0.16, 0.97, 0.72, 0.88, 0.31, 0.77, 0.21, 0.58, 0.07, 0.4, 0.12, 0.53, 1.0, 0.13, 0.81, 0.51, 0.95, 0.33]

# %% [markdown]
# ### 8.2. Lambdas

# %% [markdown]
# #### 8.2.1. Using Lambda Expressions in List Comprehensions

# %% [markdown]
# In the following challenge, we will combine two lists using a lambda expression in a list comprehension.
#
# To do this, we will need to introduce the zip function. The zip function returns an iterator of tuples.
#
# The way zip function works with list has been shown below:

# %%
#zipping a + rounded_a and printing the result 
ziplist = [list(zip(a, rounded_a))]

print(ziplist)
# Out:
# [[(0.84062117, 0.84), (0.48006452, 0.48), (0.7876326, 0.79), (0.77109654, 0.77), (0.44409793, 0.44), (0.09014516, 0.09), (0.81835917, 0.82), (0.87645456, 0.88), (0.7066597, 0.71), (0.09610873, 0.1), (0.41247947, 0.41), (0.57433389, 0.57), (0.29960807, 0.3), (0.42315023, 0.42), (0.34452557, 0.34), (0.4751035, 0.48), (0.17003563, 0.17), (0.46843998, 0.47), (0.92796258, 0.93), (0.69814654, 0.7), (0.41290051, 0.41), (0.19561071, 0.2), (0.16284783, 0.16), (0.97016248, 0.97), (0.71725408, 0.72), (0.87702738, 0.88), (0.31244595, 0.31), (0.76615487, 0.77), (0.20754036, 0.21), (0.57871812, 0.58), (0.07214068, 0.07), (0.40356048, 0.4), (0.12149553, 0.12), (0.53222417, 0.53), (0.9976855, 1.0), (0.12536346, 0.13), (0.80930099, 0.81), (0.50962849, 0.51), (0.94555126, 0.95), (0.33364763, 0.33)]]

# %% [markdown]
# In this exercise we will try to compare the elements on the same index in the two lists. We want to zip the two lists and then use a lambda expression to compare if: list1 element > list2 element

# %%
#creating lambda function to compare two elements from "a" + "rounded_a"
c = lambda a,b: "rounded is smaller" if a>b else "rounded is bigger"

comparelist = [c(a,b) for a,b in ziplist]
print(comparelist)

#can't figure out what I'm doing wrong
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-2f510e335dbc> in <module>
#       2 c = lambda a,b: "not rounded is bigger" if a>b else "rounded is bigger"
#       3
# ----> 4 comparelist = [c(a,b) for a,b in ziplist]
#       5 print(comparelist)
#
# <ipython-input-43-2f510e335dbc> in <listcomp>(.0)
#       2 c = lambda a,b: "not rounded is bigger" if a>b else "rounded is bigger"
#       3
# ----> 4 comparelist = [c(a,b) for a,b in ziplist]
#       5 print(comparelist)
#
# ValueError: too many values to unpack (expected 2)
